# %% [markdown]
# **데이터 크롤링 HTML**

# %% [markdown]
# **HTML(HyperText Markup Language)**
#
# *   확장자 : `.html`
# *   `<태그의이름>콘텐츠</태그의이름>`
# *   실제 웹 사이트를 보면 코드로 디자인 되어있다.
# *   Web은 대부분 HTML, CSS, JavaScript 문법으로 되어있다.
# *   크롤링을 하기 위해서는 문서를 분석할 줄 알아야 내가 원하는 것만 찝어올 수 있다.

# %% [markdown]
# **HTML 문법**

# %%
<html>
  <head>웹 페이지 속성에 대한 기술</head>
  <body>실제 웹 페이지에 보여지는 레이아웃, 요소 작성</body>
</html>

# %%
# 속성 및 이미지 넣기
<태그의이름 속성명="속성값">콘텐츠</태그의이름>

# 주석
<!-- -->

# %%
<html>
  <head>웹 페이지 속성에 대한 기술</head>
  <body>실제 웹 페이지에 보여지는 레이아웃, 요소 작성</body>
</html>

# %%
# 기본 예제
<!DOCTYPE html> # HTML5로 작성
<html lang="ko">
  <head>
    <meta charset="utf-8">
    <title>문서의 제목</title>
  </head>
  <body>
    웹 페이지에 표시할 콘텐츠(태그)
  </body>
</html>

# %%
# 제목 표시하기, 텍스트 넣기
<html lang="ko">
  <head>
    <meta charset="utf-8">
    <title>제목 태그별 크기 비교</title>
  </head>
  <body>
    <h1>숫자가 1일 때의 제목 텍스트</h1>
    <h2>숫자가 2일 때의 제목 텍스트</h2>
    <h3>숫자가 3일 때의 제목 텍스트</h3>
    <h4>숫자가 4일 때의 제목 텍스트</h4>
    <h5>숫자가 5일 때의 제목 텍스트</h5>
    <h6>숫자가 6일 때의 제목 텍스트</h6>
  </body>
</html>

# %%
# 수평선 표시
<body>
  <p>지금까지 스포츠 뉴스였습니다.</p>
  <hr>
  # <hr color="purple" size="10">
  <p>날씨 예보입니다. 오늘은 하루 종일 맑았지만, 내일은 비가 올 예정입니다.</p>
</body>

# %%
# 컨테이너 태그
# 요소 여럿을 묶어 관리하기 편하게 만드는 역할을 하는 태그를 컨테이너라고 한다.
<body>
  <div>
    <p>행복하고 즐거워요</p>
    <p>HTML 공부!</p>
  </div>
  <div>
    <p>슬프고 힘들어요</p>
    <p>적게 먹고 운동하는 다이어트!</p>
  </div>
</body>

# %%
# 고유한 식별자, id
# id 속성은 스크립트 및 스타일 적용 시 특정 요소를 식별하기 위한 고유 식별자
# 공백을 포함해서는 안되고, 문자나 숫자, 하이픈(-)과 언더스코어(_) 등의 기호를 사용해서 작성
<body>
  <div id="study">
    <p>행복하고 즐거워요</p>
    <p>HTML 공부!</p>
  </div>
  <div id="diet">
    <p>슬프고 힘들어요</p>
    <p>적게 먹고 운동하는 다이어트!</p>
  </div>
</body>

# %%
# 그룹화 식별자, class
# class 속성은 여러 요소에 같은 이름의 식별자를 지정하여 요소를 그룹화할 수 있는 식별자
<body>
  <div>
    <p class="text content">행복하고 즐거워요</p>
    <p class="text content">HTML 공부!</p>
  </div>
  <div>
    <p class="text content">슬프고 힘들어요</p>
    <p class="text content">적게 먹고 운동하는 다이어트!</p>
  </div>
</body>

# %%
# 목록 만들기
# 순서 없는 목록(Unordered List)
<body>
  <h1>항목 태그는 같은 것을 쓴다</h1>
  <ul>
    <li>강아지</li>
    <li>고양이</li>
    <li>거북이</li>
    <li>햄스터</li>
  </ul>
</body>

# 순서 있는 목록(Ordered List)
<body>
  <h1>항목 태그는 같은 것을 쓴다</h1>
  <ol>
    <li>스타벅스</li>
    <li>커피빈</li>
    <li>파스쿠찌</li>
    <li>이디야</li>
  </ol>
</body>

# %%
# 표 만들기
# 표 요소는 구조상 행(Row)과 열(Column)로 이루어져 있고,
# 행과 열이 만나는 지점인 셀(Cell)이 하나의 항목을 나타내는 역할을 한다.
<body>
  <table border="1"> # 표
    <tr> # 행
      <th>한국 선수</th> # 행의 제목
      <th>일본 선수</th> # 행의 제목
      <th>미국 선수</th> # 행의 제목
    </tr>
    <tr> # 행
      <td>김철수</td> # 행의 항목
      <td>오오다</td> # 행의 항목
      <td>제임스</td> # 행의 항목
    </tr>
  </table>
</body>

# %%
# 입력 받기
<body>
  <h1>type="text"</h1>
  <input type="text" placeholder="텍스트를 입력하세요" maxlength="15" size="20">
</body>

# %% [markdown]
# **Selenium**
#
# *   셀레늄은 웹 웹을 테스트에 사용하는 프레임워크이다.
# *   웹 앱을 테스트 하는 용도로 개발된 Selenium을 응용해서 스크래핑에 사용한다.
# *   특히 웹 드라이버(Web Driver)를 사용해서 파이썬으로 웹 브라우저를 제어한다.

# %% [markdown]
# **Selenium 실습**
#
# *   크롬 웹 브라우저 설치 (최신 버전)
# *   크롬 웹 드라이버 다운로드 (https://chromedriver.chromium.org/downloads)
# *   파이썬 셀레늄 모듈을 설치
# *   `pip install selenium` 설치

# %%
# 파이썬으로 selenium 설치
pip install selenium

# %%
# 윈도우
from selenium import webdriver
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://www.naver.com")

# %%
# 맥 & 리눅스
from selenium import webdriver
driver = webdriver.Chrome("chromedriver")
driver.get("https://www.naver.com")

# %%
# 스크래핑을 끝내고 웹 브라우저를 종료하고 싶다면 quit() 메서드를 사용
driver.quit()

# %%
# driver 객체에 정의된 get() 메서드는 웹페이지로 이동하는 기능을 제공
# 이동하려는 웹 페이지의 주소를 문자열 형태로 전달하며
# 사람이 주소 표시줄에 URL을 입력하고, 엔터를 누르는 것과 같다.
url = "https://www.naver.com"
driver.get(url)

# %%
from selenium import webdriver
import time

driver = webdriver.Chrome("chromedriver")
driver.get("https://www.naver.com")

# 200초 동안 멈추기
time.sleep(200)

# %% [markdown]
# **이동하기**

# %%
# 네이버에서 다음으로 이동하기
from selenium import webdriver
import time

driver = webdriver.Chrome("chromedriver")

# 네이버로 이동하기
url = "https://www.naver.com"
driver.get(url)

time.sleep(3)

# 다음으로 이동하기
url = "https://www.daum.net"
driver.get(url)

# 종료
driver.quit()

# %% [markdown]
# **마우스 입력**

# %%
# 주의! 네이버는 패턴을 바꾸기도 한다.
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome("chromedriver")

url = "https://www.naver.com"
driver.get(url)

# 마우스 입력
driver.find_element(By.CSS_SELECTOR, '#NM_FAVORITE > div.group_nav > ul.list_nav.NM_FAVORITE_LIST > li:nth-child(8) > a').click()
time.sleep(5)

# 마우스 입력
driver.find_element(By.CSS_SELECTOR, '#menu > li:nth-child(3) > a').click()
time.sleep(200)

# %% [markdown]
# **키보드 입력**

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome("chromedriver")

url = "https://www.naver.com"
driver.get(url)

# 키보드 입력
elem = driver.find_element(By.CSS_SELECTOR, '#APjFqb')
elem.send_keys("코로나") # 엔터키 입력
elem.send_keys(Keys.RETURN) # 검색키 입력
time.sleep(200)

# %% [markdown]
# **Request**
#
# *   Python 프로그래밍 언어용, HTTP 요청을 보낼 수 있도록 기능을 제공하는 라이브러리이다.
# *   웹 파싱은 웹 상의 자연어, 컴퓨터 언어 등의 일련의 문자열들을 분석하는 프로세스이다.
# *   웹 스크래핑은 다양한 웹사이트로부터 데이터를 추출하는 기술이다.
# *   BeautifulSoup : 웹 페이지의 정보를 쉽게 스크랩할 수 있도록 기능을 제공하는 라이브러리이다.

# %%
# 파이썬으로 selenium 설치
pip install requests

# 파이썬으로 selenium 설치
pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.naver.com"

result = requests.get(url) # <Response [200]> 반환
html = result.text # html 내용 반환

soup = BeautifulSoup(html, "html.parser") # html을 정확한 규격으로 나눠준다.
print(soup)
