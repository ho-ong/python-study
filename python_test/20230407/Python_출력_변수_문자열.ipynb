# %% [markdown]
# 001 print 기초
#
# 화면에 Hello World 문자열을 출력하세요.

# %%
# 문자열 : '' or ""
# print() : 출력
print('Hello World')
print("Hello World")
# Out:
# Hello World
# Hello World

# %% [markdown]
# 002 print 기초
#
# 화면에 Mary's cosmetics을 출력하세요. (중간에 '가 있음에 주의하세요)

# %%
# 큰 따옴표 내 ' 사용 or \' 사용
print("Mary\'s cosmetics")
print("Mary\'s cosmetics")
# Out:
# Mary's cosmetics
# Mary's cosmetics

# %% [markdown]
# 003 print 기초
#
# 화면에 아래 문장을 출력하세요. (중간에 "가 있음에 주의하세요.)
#
# 신씨가 소리질렀다. "도둑이야".

# %%
# 작은 따옴표 내 " 사용 or \" 사용
print('신씨가 소리질렀다. "도둑이야".')
print("신씨가 소리질렀다. \"도둑이야\".")
# Out:
# 신씨가 소리질렀다. "도둑이야".
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# 004 print 기초
#
# 화면에 "C:\Windows"를 출력하세요.

# %%
# \\ 사용
print("C:\\Windows")
# Out:
# C:\Windows

# %% [markdown]
# 005 print 탭과 줄바꿈
#
# 다음 코드를 실행해보고 \t와 \n의 역할을 설명해보세요.
#
# print("안녕하세요.\n만나서\t\t반갑습니다.")

# %%
# \t는 탭, \n은 개행(줄바꿈)의 역할을 한다.

# %% [markdown]
# 006 print 여러 데이터 출력
#
# print 함수에 두 개의 단어를 입력한 예제입니다. 아래 코드의 출력 결과를 예상해봅시다.
#
# print ("오늘은", "일요일")

# %%
# ,로 인해 공백으로 구분되어 출력

# 오늘은 일요일

# %% [markdown]
# 007 print 기초
#
# print( sep=';') 함수를 사용하여 다음과 같이 출력하세요.
#
# naver;kakao;sk;samsung

# %%
# sep() : 구분 및 분리, "" 내 어떻게 구분 및 분리할지 추가
print("naver", "kakao", "sk", "samsung", sep = ";")
# Out:
# naver;kakao;sk;samsung

# %% [markdown]
# 008 print 기초
#
# print() 함수를 사용하여 다음과 같이 출력하세요.
#
# naver/kakao/sk/samsung

# %%
# sep() : 구분 및 분리, "" 내 어떻게 구분 및 분리할지 추가
print("naver", "kakao", "sk", "samsung", sep = "/")
# Out:
# naver/kakao/sk/samsung

# %% [markdown]
# 009 print 줄바꿈
#
# 다음 코드를 수정하여 줄바꿈이 없이 출력하세요. (힌트: end='') print 함수는 두 번 사용합니다. 세미콜론 (;)은 한줄에 여러 개의 명령을 작성하기 위해 사용합니다.
#
# print("first");print("second")

# %%
# end : 마지막 처리, "" 내 어떻게 마지막을 처리할지 추가
print("first", end = ";")
print("second")
# Out:
# first;second

# %% [markdown]
# 010 연산 결과 출력
#
# 5/3의 결과를 화면에 출력하세요.

# %%
# / : 나누기
print(5 / 3)
# Out:
# 1.6666666666666667

# %% [markdown]
# 011 변수 사용하기
#
# samsung라는 변수로 50,000원을 정의 해보세요. samsung 주식 10주를 보유하고 있을 때 총 평가금액을 출력하세요.

# %%
# 변수 = 값
# samsung 주식 10주 보유 = samsung * 10
samsung = 50000
print(samsung * 10)
# Out:
# 500000

# %% [markdown]
# 012 변수 사용하기
#
# 다음 표는 삼성전자의 일부 투자정보입니다. 변수를 사용해서 시가총액, 현재가, PER 등을 정의해보세요.
#
# ![image.png](data:image/png;base64,...)

# %%
# 변수는 한글로도 기입이 가능하지만, 가능한 영어로 기입하기
시가총액 = "298조"
현재가 = "50,000원"
PER = 15.79
print(시가총액, 현재가, PER)
# Out:
# 298조 50,000원 15.79

# %% [markdown]
# 013 문자열 출력
#
# 변수 s와 t에는 각각 문자열이 바인딩 되어있습니다.
#
# s = "hello"
#
# t = "python"
#
# 두 변수를 이용하여 아래와 같이 출력해보세요.
#
# 실행 예:
# hello! python

# %%
s = "hello"
t = "python"

# +를 사용한 문자열 연결
print(s + "! " + t)

# end를 사용한 문자열 연결
print(s, end = "! ")
print(t)
# Out:
# hello! python
# hello! python

# %% [markdown]
# 014 파이썬을 이용한 값 계산
#
# 아래 코드의 실행 결과를 예상해보세요.
#
# 2 + 2 * 3

# %%
# 사칙연산은 곱하기 먼저 실행
# 2 * 3 실행 후 + 2
# 그러므로 결과는 8

# 8

# %% [markdown]
# 015 type 함수
#
# type() 함수는 데이터 타입을 판별합니다. 변수 a에는 128 숫자가 바인딩돼 있어 type 함수가 int (정수)형임을 알려줍니다.
#
# a = 128
#
# print(type(a))
#
# 출력: <class 'int'>
#
# 아래 변수에 바인딩된 값의 타입을 판별해보세요.
#
# a = "132"

# %%
# type() : 데이터의 타입 판별
a = "132"
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# 016 문자열을 정수로 변환
#
# 문자열 '720'를 정수형으로 변환해보세요.
#
# num_str = "720"

# %%
# int() : 정수형 변환
num_str = "720"
print(int(num_str))
# Out:
# 720

# %% [markdown]
# 017 정수를 문자열 100으로 변환
#
# 정수 100을 문자열 '100'으로 변환해보세요.
#
# num = 100

# %%
# str() : 문자열 변환
num = 100
print(str(num))
# Out:
# 100

# %% [markdown]
# 018 문자열을 실수로 변환
#
# 문자열 "15.79"를 실수(float) 타입으로 변환해보세요.

# %%
# float() : 실수형 변환
str = "15.79"
print(float(str))
# Out:
# 15.79

# %% [markdown]
# 019 문자열을 정수로 변환
#
# year라는 변수가 문자열 타입의 연도를 바인딩하고 있습니다. 이를 정수로 변환한 후 최근 3년의 연도를 화면에 출력해보세요.
#
# year = "2020"

# %%
# int() : 정수형 변환
# 최근 3년의 연도이므로 - 3
year = "2020"
print(int(year) - 3)
# Out:
# 2017

# %% [markdown]
# 020 파이썬 계산
#
# 에이컨이 월 48,584원에 무이자 36개월의 조건으로 홈쇼핑에서 판매되고 있습니다.
#
# 총 금액은 계산한 후 이를 화면에 출력해보세요. (변수사용하기)

# %%
# 에어컨 월 비용 48,584원 X 할부 36개월
a = 48584
m = 36
print(a * m)
# Out:
# 1749024

# %% [markdown]
# 021 문자열 인덱싱
#
# letters가 바인딩하는 문자열에서 첫번째와 세번째 문자를 출력하세요.
#
# letters = 'python'
#
# 실행 예: p t

# %%
# 변수[] : 인덱싱 (인덱스 번호는 0부터 시작)
letters = 'python'
print(letters[0]) # p
print(letters[2]) # t
# Out:
# p
# t

# %% [markdown]
# 022 문자열 슬라이싱
#
# 자동차 번호가 다음과 같을 때 뒤에 4자리만 출력하세요.
#
# license_plate = "24가 2210"
#
# 실행 예: 2210

# %%
# 변수[처음:끝:간격] : 슬라이싱 (인덱스 번호는 0부터 시작)
license_plate = "24가 2210"
print(license_plate[4:])
# Out:
# 2210

# %% [markdown]
# 023 문자열 인덱싱
#
# 아래의 문자열에서 '홀' 만 출력하세요.
#
# string = "홀짝홀짝홀짝"
#
# 실행 예:
# 홀홀홀

# %%
# 변수[처음:끝:간격] : 슬라이싱 (인덱스 번호는 0부터 시작)
string = "홀짝홀짝홀짝"
print(string[0::2])
# Out:
# 홀홀홀

# %% [markdown]
# 024 문자열 슬라이싱 (어려움)
#
# 문자열을 거꾸로 뒤집어 출력하세요.
#
# string = "PYTHON"
#
# 실행 예:
# NOHTYP

# %%
# 변수[처음:끝:간격] : 슬라이싱 (인덱스 번호는 0부터 시작)
# 인버스 인덱싱 : 음수를 사용한 인덱싱
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %% [markdown]
# 025 문자열 치환 (어려움)
#
# 아래의 전화번호에서 하이푼 ('-')을 제거하고 출력하세요.
#
# phone_number = "010-1111-2222"
#
# 실행 예:
# 010 1111 2222

# %%
# replace() : 교체 및 치환, "" 내 어떻게 교체 및 치환할지 추가
phone_number = "010-1111-2222"
print(phone_number.replace("-", " "))
# Out:
# 010 1111 2222

# %% [markdown]
# 026 문자열 다루기 (어려움)
#
# 25번 문제의 전화번호를 아래와 같이 모두 붙여 출력하세요.
#
# 실행 예
# 01011112222

# %%
# replace() : 교체 및 치환, "" 내 어떻게 교체 및 치환할지 추가
phone_number = "010-1111-2222"
print(phone_number.replace("-", ""))
# Out:
# 01011112222

# %% [markdown]
# 027 문자열 다루기
#
# url 에 저장된 웹 페이지 주소에서 도메인을 출력하세요.
#
# url = "http://sharebook.kr"
#
# 실행 예:
# kr

# %%
# 인버스 인덱싱 : 음수를 사용한 인덱싱
url = "http://sharebook.kr"
print(url[-2:])
# Out:
# kr

# %% [markdown]
# 028 문자열은 immutable
#
# 아래 코드의 실행 결과를 예상해보세요.
#
# lang = 'python'
#
# lang[0] = 'P'
#
# print(lang)

# %%
# 인덱스 번호 0의 'p'가 'P'로 변환되어 출력

# Python

# %% [markdown]
# 029 replace 메서드
#
# 아래 문자열에서 소문자 'a'를 대문자 'A'로 변경하세요.
#
# string = 'abcdfe2a354a32a'
#
# 실행 예:
# Abcdfe2A354A32A

# %%
# replace() : 교체 및 치환, "" 내 어떻게 교체 및 치환할지 추가
string = 'abcdfe2a354a32a'
print(string.replace("a", "A"))
# Out:
# Abcdfe2A354A32A

# %% [markdown]
# 030 replace 메서드
#
# 아래 코드의 실행 결과를 예상해보세요.
#
# string = 'abcd'
#
# string.replace('b', 'B')
#
# print(string)

# %%
# 'abcd' 문자열의 'b'가 'B'로 변환되어 출력

# aBcd

# %% [markdown]
# 031 문자열 합치기
#
# 아래 코드의 실행 결과를 예상해보세요.
#
# a = "3"
#
# b = "4"
#
# print(a + b)

# %%
# 문자열의 합 : "3" + "4" = "34"
# 정수형의 합 : 3 + 4 = 7

# 34

# %% [markdown]
# 032 문자열 곱하기
#
# 아래 코드의 실행 결과를 예상해보세요.
#
# print("Hi" * 3)

# %%
# 문자열의 곱 : "Hi" * 3 = "HiHiHi"
# 정수형의 곱 : 2 * 3 = 6

# HiHiHi

# %% [markdown]
# 033 문자열 곱하기
#
# 화면에 '-'를 80개 출력하세요.
#
# 실행 예:--------------------------------------------------------------------------------

# %%
# 문자열의 곱 : "-" * 80 = "--------------------------------------------------------------------------------"
str = "-"
print(str * 80)
# Out:
# --------------------------------------------------------------------------------

# %% [markdown]
# 034 문자열 곱하기
#
# 변수에 다음과 같은 문자열이 바인딩되어 있습니다.
#
# t1 = 'python'
#
# t2 = 'java'
#
# 변수에 문자열 더하기와 문자열 곱하기를 사용해서 아래와 같이 출력해보세요.
#
# 실행 예:
# python java python java python java python java

# %%
# 문자열의 곱 : t1 + " " + t2 + " " = python java 
t1 = 'python'
t2 = 'java'

# +를 사용한 문자열 연결 후 사칙연산
print((t1 + " " + t2 + " ") * 4)

# 변수 별도 생성 후 사칙연산
t3 = t1 + " " + t2 + " "
print(t3 * 4)
# Out:
# python java python java python java python java
# python java python java python java python java

# %% [markdown]
# 035 문자열 출력
#
# 변수에 다음과 같이 문자열과 정수가 정의되어 있을 때 다음과 같이 출력해보세요.
#
# name1 = "김민수"
#
# age1 = 10
#
# name2 = "이철희"
#
# age2 = 13
#
# 이름: 김민수 나이: 10
#
# 이름: 이철희 나이: 13

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
print("이름: " + name1 + " 나이:", age1)
print("이름: " + name2 + " 나이:", age2)
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# 036 문자열 출력
#
# 문자열의 format( ) 메서드를 사용해서 035번 문제를 다시 풀어보세요.
#
# 힌트: print("{} {}".format(A,B))

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
print("이름: {} 나이: {}".format(name1, age1))
print("이름: {} 나이: {}".format(name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# 037 문자열 출력
#
# 파이썬 3.6부터 지원하는 f-string을 사용해서 035번 문제를 다시 풀어보세요.
#
# 힌트: print(f"{A}")

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
print(f"이름: {name1} 나이: {age1}")
print(f"이름: {name2} 나이: {age2}")
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %% [markdown]
# 038 컴마 제거하기
#
# 삼성전자의 상장주식수가 다음과 같습니다. 컴마를 제거한 후 이를 정수 타입으로 변환해보세요.
#
# samsung = "5,969,782,550"

# %%
# replace()로 , 제거 후 int()로 정수형 변환
samsung = "5,969,782,550"
print(int(samsung.replace(",", "")))
# Out:
# 5969782550

# %% [markdown]
# 039 문자열 슬라이싱
#
# 다음과 같은 문자열에서 '2020/03'만 출력하세요.
#
# test = "2020/03(E) (IFRS연결)"

# %%
# 변수[처음:끝:간격] : 슬라이싱 (인덱스 번호는 0부터 시작)
test = "2020/03(E) (IFRS연결)"
print(test[:7])
# Out:
# 2020/03

# %% [markdown]
# 040 strip 메서드 (어려움)
#
# 문자열의 좌우의 공백이 있을 때 이를 제거해보세요.

# %%
# strip() : 공백 제거
data = "   삼성전자    "
print(data.strip())
# Out:
# 삼성전자

# %% [markdown]
# 041 upper 메서드
#
# 다음과 같은 문자열이 있을 때 이를 대문자 BTC_KRW로 변경하세요.
#
# ticker = "btc_krw"

# %%
# upper() : 대문자 변환
ticker = "btc_krw"
print(ticker.upper())
# Out:
# BTC_KRW

# %% [markdown]
# 042 lower 메서드
#
# 다음과 같은 문자열이 있을 때 이를 소문자 btc_krw로 변경하세요.
#
# ticker = "BTC_KRW"

# %%
# lower() : 소문자 변환
ticker = "BTC_KRW"
print(ticker.lower())
# Out:
# btc_krw

# %% [markdown]
# 043 capitalize 메서드
#
# 문자열 'hello'가 있을 때 이를 'Hello'로 변경해보세요.

# %%
# capitalize() : 첫 글자 대문자 변환
str = "hello"
print(str.capitalize())
# Out:
# Hello

# %% [markdown]
# 044 endswith 메서드
#
# 파일 이름이 문자열로 저장되어 있을 때 endswith 메서드를 사용해서 파일 이름이 'xlsx'로 끝나는지 확인해보세요.
#
# file_name = "보고서.xlsx"

# %%
# endswith() : 접미사 체크 (True or False)
file_name = "보고서.xlsx"
print(file_name.endswith("xlsx"))
# Out:
# True

# %% [markdown]
# 045 endswith 메서드
#
# 파일 이름이 문자열로 저장되어 있을 때 endswith 메서드를 사용해서 파일 이름이 'xlsx' 또는 'xls'로 끝나는지 확인해보세요.
#
# file_name = "보고서.xlsx"

# %%
# endswith() : 접미사 체크 (True or False)
file_name = "보고서.xlsx"
print(file_name.endswith("xlsx" or "xls"))
# Out:
# True

# %% [markdown]
# 046 startswith 메서드
#
# 파일 이름이 문자열로 저장되어 있을 때 startswith 메서드를 사용해서 파일 이름이 '2020'로 시작하는지 확인해보세요.
#
# file_name = "2020_보고서.xlsx"

# %%
# startswith() : 접두사 체크 (True or False)
file_name = "2020_보고서.xlsx"
print(file_name.startswith("2020"))
# Out:
# True

# %% [markdown]
# 047 split 메서드
#
# 다음과 같은 문자열이 있을 때 공백을 기준으로 문자열을 나눠보세요.
#
# a = "hello world"

# %%
# split() : 분리 후 리스트로 변환
a = "hello world"
print(a.split(" "))
# Out:
# ['hello', 'world']

# %% [markdown]
# 048 split 메서드
#
# 다음과 같이 문자열이 있을 때 btc와 krw로 나눠보세요.
#
# ticker = "btc_krw"

# %%
# split() : 분리 후 리스트로 변환
ticker = "btc_krw"
print(ticker.split("_"))
# Out:
# ['btc', 'krw']

# %% [markdown]
# 049 split 메서드
#
# 다음과 같이 날짜를 표현하는 문자열이 있을 때 연도, 월, 일로 나눠보세요.
#
# date = "2020-05-01"

# %%
# split() : 분리 후 리스트로 변환
date = "2020-05-01"
print(date.split("-"))
# Out:
# ['2020', '05', '01']

# %% [markdown]
# 050 rstrip 메서드
#
# 문자열의 오른쪽에 공백이 있을 때 이를 제거해보세요.

# %%
# rstrip() : 오른쪽 공백 제거
# lstrip() : 왼쪽 공백 제거
data = "039490     "
print(data.rstrip())
# Out:
# 039490
