# %% [markdown]
# 01 파일 쓰기
#
# 작업디렉토리에 '매수종목1.txt' 파일을 생성한 후 다음과 같이 종목코드를 파일에 써보세요.
#
# ```
# 005930
# 005380
# 035420
# ```

# %%
# open() : 파일 열기
# mode = "w" : 쓰기 모드
# encoding = "utf-8" : 유니코드 인코딩 (영어, 한글 등 지원)
f = open("/content/매수종목1.txt", mode = "w", encoding = "utf-8")

# write() : 파일에 내용 쓰기
# close() : 파일 닫기
f.write("005930\n")
f.write("005380\n")
f.write("035420")
f.close()

# %% [markdown]
# 02 파일 쓰기
#
# 작업디렉토리에 '매수종목2.txt' 파일을 생성한 후 다음과 같이 종목코드와 종목명을 파일에 써보세요.
#
# ```
# 005930 삼성전자
# 005380 현대차
# 035420 NAVER
# ```

# %%
# open() : 파일 열기
# mode = "w" : 쓰기 모드
# encoding = "utf-8" : 유니코드 인코딩 (영어, 한글 등 지원)
f = open("/content/매수종목2.txt", mode = "w", encoding = "utf-8")

# write() : 파일에 내용 쓰기
# close() : 파일 닫기
f.write("005930 삼성전자\n")
f.write("005380 현대차\n")
f.write("035420 NAVER")
f.close()

# %% [markdown]
# 03 파일 읽기
#
# 작업디렉토리에 생성한 '매수종목1.txt' 파일을 읽은 후 종목코드를 리스트에 저장해보세요.
#
# ```
# 005930
# 005380
# 035420
# ```

# %%
# open() : 파일 열기
# mode = "r" : 읽기 모드
# encoding = "utf-8" : 유니코드 인코딩 (영어, 한글 등 지원)
f = open("/content/매수종목1.txt", mode = "r", encoding = "utf-8")

# 리스트 생성
list = []
for i in f:
  # strip() : 공백 및 문자 제거
  # append() : 리스트에 요소 추가
  l = i.strip("\n")
  list.append(l)

print(list)
f.close()
# Out:
# ['005930', '005380', '035420']

# %% [markdown]
# 04 파일 읽기
#
# 바탕화면에 생성한 '매수종목2.txt' 파일을 읽은 후 종목코드와 종목명을 딕셔너리로 저장해보세요. 종목명을 key로 종목명을 value로 저장합니다.
#
# ```
# 005930 삼성전자
# 005380 현대차
# 035420 NAVER
# ```

# %%
# open() : 파일 열기
# mode = "r" : 읽기 모드
# encoding = "utf-8" : 유니코드 인코딩 (영어, 한글 등 지원)
f = open("/content/매수종목2.txt", mode = "r", encoding = "utf-8")

# 딕셔너리 생성
dict = {}
for i in f:
  # strip() : 공백 제거, 특정 문자 제거
  # split() : 분리 후 리스트로 변환
  l = i.strip("\n")
  key, value = i.split() # '005930', '삼성전자', '005380', '현대차', '035420', 'NAVER'
  # 딕셔너리[key]에 value 할당
  dict[key] = value

print(dict)
f.close()
# Out:
# {'005930': '삼성전자', '005380': '현대차', '035420': 'NAVER'}

# %% [markdown]
# 05 예외처리
#
# 문자열 PER (Price to Earning Ratio) 값을 실수로 변환할 때 에러가 발생합니다. 예외처리를 통해 에러가 발생하는 PER은 0으로 출력하세요.
#
# ```
# per = ["10.31", "", "8.00"]
#
# for i in per:
#     print(float(i))
# ```

# %%
per = ["10.31", "", "8.00"]

for i in per:
  try: # 예외가 발생할 수 있는 문장
    print(float(i))
  except: # 예외를 처리하는 문장
    print(0)
# Out:
# 10.31
# 0
# 8.0

# %% [markdown]
# 06 예외처리 및 리스트에 저장
#
# 문자열로 표현된 PER 값을 실수로 변환한 후 이를 새로운 리스트에 저장해보세요.
#
# ```
# per = ["10.31", "", "8.00"]
#
# for i in per:
#     print(float(per))
# ```

# %%
per = ["10.31", "", "8.00"]

# 리스트 생성
per_list = []

for i in per:
  try: # 예외가 발생할 수 있는 문장
    f = float(i)
  except: # 예외를 처리하는 문장
    f = 0
    
  # append() : 리스트에 요소 추가
  per_list.append(f)

print(per_list)
# Out:
# [10.31, 0, 8.0]

# %% [markdown]
# 07 특정 예외만 처리하기
#
# 어떤 값을 0으로 나누면 ZeroDivisionError 에러가 발생합니다. try ~ except로 모든 에러에 대해 예외처리하지 말고 ZeroDivisionError 에러만 예외처리해보세요.

# %%
# ZeroDivisionError : 0으로 나누면 발생하는 에러
try: # 예외가 발생할 수 있는 문장
  b = 3 / 0
except ZeroDivisionError: # 예외를 처리하는 문장
  print("0으로 나누면 발생하는 에러")
# Out:
# 0으로 나누면 발생하는 에러

# %% [markdown]
# 08 예외의 메시지 출력하기
#
# 다음과 같은 코드 구조를 사용하면 예외 발생 시 에러 메시지를 변수로 바인딩할 수 있습니다.
#
# ```
# try:
#     실행코드
# except 예외 as 변수:
#     예외처리코드
# 리스트의 인덱싱에 대해 에러를 출력해보세요.
#
# data = [1, 2, 3]
#
# for i in range(5)
#     print(data[i])
# ```

# %%
data = [1, 2, 3]

# IndexError : 인덱싱 에러
for i in range(5):
  try: # 예외가 발생할 수 있는 문장
    print(data[i])
  except IndexError as e: # 예외를 처리하는 문장 (as 별칭)
    print(e)
# Out:
# 1
# 2
# 3
# list index out of range
# list index out of range

# %% [markdown]
# 09 try, except, else, finally 구조 사용해보기
#
# 파이썬 예외처리는 다음과 같은 구조를 가질 수 있습니다.
#
# ```
# try:
#     실행 코드
# except:
#     예외가 발생했을 때 수행할 코드
# else:
#     예외가 발생하지 않았을 때 수행할 코드
# finally:
#     예외 발생 여부와 상관없이 항상 수행할 코드
#
# ```
#
# 아래의 코드에 대해서 예외처리를 사용하고 try, except, else, finally에 적당한 코드를 작성해봅시다. else와 finally는 적당한 문구를 print하시면 됩니다.
#
# ```
# per = ["10.31", "", "8.00"]
#
# for i in per:
#     print(float(per))
#
# ```

# %%
per = ["10.31", "", "8.00"]

for i in per:
  try: # 실행 코드
    print(float(i))
  except: # 예외가 발생했을 때 수행할 코드
    print(0)
  else: # 예외가 발생하지 않았을 때 수행할 코드
    print("예외가 발생하지 않았다.")
  finally: # 예외 발생 여부와 상관없이 항상 수행할 코드
    print("예외 발생 여부와 상관없다.")
# Out:
# 10.31
# 예외가 발생하지 않았다.
# 예외 발생 여부와 상관없다.
# 0
# 예외 발생 여부와 상관없다.
# 8.0
# 예외가 발생하지 않았다.
# 예외 발생 여부와 상관없다.
